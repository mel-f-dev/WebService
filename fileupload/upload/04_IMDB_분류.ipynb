# %% [markdown]
# # Example: IMDb movie review 분류

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ### The IMDB dataset
#
#
# - A set of 50,000 highly-polarized reviews from the Internet Movie Database
#     - 25,000 reviews for training and 25,000 reviews for testing
#     - 50% negative(label=0) and 50% positive(label=1) reviews

# %% [markdown]
# ### Loading data

# %%
with open("imdb_data/X_train.pkl", 'rb') as f:
    X_train = pickle.load(f)
    
with open('imdb_data/y_train.pkl', 'rb') as f:
    y_train = pickle.load(f)
    
with open('imdb_data/X_test.pkl', 'rb') as f:
    X_test = pickle.load(f)
    
with open('imdb_data/y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

# %%
type(X_train), type(y_train)
# Out:
# (list, numpy.ndarray)

# %%
y_train[0]
# Out:
# 1

# %%
X_train[0]
# Out:
# 'zero day lead think even think two boy young men would commit mutual suicid via slaughter classmat captur must beyond bizarr mode two human decid withdraw common civil order defin mutual world via coupl destruct perfect movi given money time filmmak actor remark product term explain motiv action two young suicid murder better eleph term film get rationalist skin far far better film almost anyth like see flaw honest terribl honesti'

# %%
# Feature Vectorization (텍스트->숫자)
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=10000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((25000, 10000), (25000, 10000))

# %%
y_train.dtype
# Out:
# dtype('int32')

# %%
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %% [markdown]
# ### 모델 생성
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras import models, layers

# %%
# 모델 생성
model = models.Sequential()
# layer 추가 - Dense layer(fully connected layer)
# 은닉층(hidden layer)
model.add(layers.Dense(units=16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(units=16, activation='relu'))
# 출력층(output layer)
model.add(layers.Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 컴파일

# %%
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=['accuracy'])

# %% [markdown]
# ### 학습(fit) - 검증(Validation) 셋을 이용
#
# - Training set을 train과 validation set으로 나눠 학습과 검증을 같이 처리한다.
#     - 25000 중 15000를 train으로 10000은 validation set으로 사용한다.

# %%
X_val = X_train_tfidf[:15000]
X_part = X_train_tfidf[15000:]

y_val = y_train[:15000]
y_part = y_train[15000:]

# %%
X_val.shape, X_part.shape, y_val.shape, y_part.shape
# Out:
# ((15000, 10000), (10000, 10000), (15000,), (10000,))

# %%
hist = model.fit(X_val, y_val, epochs=20, batch_size=128,
                 validation_data=(X_part, y_part)   )
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'scipy.sparse.csr.csr_matrix'>, <class 'NoneType'>
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 4s 283us/sample - loss: 0.5911 - accuracy: 0.7607 - val_loss: 0.4255 - val_accuracy: 0.8675
# Epoch 2/20
# 15000/15000 [==============================] - 4s 255us/sample - loss: 0.2909 - accuracy: 0.9059 - val_loss: 0.2792 - val_accuracy: 0.8865
# Epoch 3/20
# 15000/15000 [==============================] - 4s 252us/sample - loss: 0.1725 - accuracy: 0.9426 - val_loss: 0.2806 - val_accuracy: 0.8804
# Epoch 4/20
# 15000/15000 [==============================] - 4s 254us/sample - loss: 0.1182 - accuracy: 0.9659 - val_loss: 0.2998 - val_accuracy: 0.8771
# Epoch 5/20
# 15000/15000 [==============================] - 4s 250us/sample - loss: 0.0834 - accuracy: 0.9782 - val_loss: 0.3354 - val_accuracy: 0.8715
# Epoch 6/20
# 15000/15000 [==============================] - 4s 267us/sample - loss: 0.0580 - accuracy: 0.9885 - val_loss: 0.3760 - val_accuracy: 0.8675
# Epoch 7/20
# 15000/15000 [==============================] - 4s 264us/sample - loss: 0.0403 - accuracy: 0.9939 - val_loss: 0.4144 - val_accuracy: 0.8648
# Epoch 8/20
# 15000/15000 [==============================] - 4s 278us/sample - loss: 0.0274 - accuracy: 0.9965 - val_loss: 0.4608 - val_accuracy: 0.8628
# Epoch 9/20
# 15000/15000 [==============================] - 4s 250us/sample - loss: 0.0184 - accuracy: 0.9983 - val_loss: 0.4987 - val_accuracy: 0.8608
# Epoch 10/20
# 15000/15000 [==============================] - 4s 243us/sample - loss: 0.0126 - accuracy: 0.9987 - val_loss: 0.5391 - val_accuracy: 0.8580
# Epoch 11/20
# 15000/15000 [==============================] - 4s 239us/sample - loss: 0.0085 - accuracy: 0.9992 - val_loss: 0.5741 - val_accuracy: 0.8569
# Epoch 12/20
# 15000/15000 [==============================] - 4s 240us/sample - loss: 0.0058 - accuracy: 0.9996 - val_loss: 0.6083 - val_accuracy: 0.8569
# Epoch 13/20
# 15000/15000 [==============================] - 4s 239us/sample - loss: 0.0041 - accuracy: 0.9998 - val_loss: 0.6331 - val_accuracy: 0.8572
# Epoch 14/20
# 15000/15000 [==============================] - 4s 242us/sample - loss: 0.0030 - accuracy: 0.9999 - val_loss: 0.6597 - val_accuracy: 0.8567
# Epoch 15/20
# 15000/15000 [==============================] - 4s 240us/sample - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.6853 - val_accuracy: 0.8551
# Epoch 16/20
# 15000/15000 [==============================] - 4s 242us/sample - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.7035 - val_accuracy: 0.8551
# Epoch 17/20
# 15000/15000 [==============================] - 4s 262us/sample - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.7269 - val_accuracy: 0.8550
# Epoch 18/20
# 15000/15000 [==============================] - 4s 252us/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7461 - val_accuracy: 0.8544
# Epoch 19/20
# 15000/15000 [==============================] - 4s 256us/sample - loss: 8.7694e-04 - accuracy: 1.0000 - val_loss: 0.7634 - val_accuracy: 0.8539
# Epoch 20/20
# 15000/15000 [==============================] - 4s 256us/sample - loss: 7.3772e-04 - accuracy: 1.0000 - val_loss: 0.7812 - val_accuracy: 0.8538

# %% [markdown]
# ### epoch 별 평가 지표 확인

# %%
{'loss':[20], 'accuracy':[20], 'val_loss':[], 'val_accuracy':[]}

# %%
hist.history
# Out:
# {'loss': [0.59108985303243,
#   0.2908552343606949,
#   0.17245565849542618,
#   0.11824593952496847,
#   0.08341426749229432,
#   0.05803779574433963,
#   0.040315796533226964,
#   0.027396858236193658,
#   0.018428700511654218,
#   0.012588502945005894,
#   0.008483486987898747,
#   0.005847868716468414,
#   0.004083667775491873,
#   0.0029654626975456873,
#   0.002340369002521038,
#   0.0019039251039425532,
#   0.0014464605361844103,
#   0.0010593914216384293,
#   0.0008769378862654169,
#   0.0007377184530642505],
#  'accuracy': [0.7607333,
#   0.9059333,
#   0.9426,
#   0.9659333,
#   0.9782,
#   0.9885333,
#   0.9938667,
#   0.99653333,
#   0.99826664,
#   0.99873334,
#   0.9992,
#   0.9996,
#   0.9998,
#   0.99986666,
#   0.99993336,
#   0.99993336,
#   0.99993336,
#   1.0,
#   1.0,
#   1.0],
#  'val_loss': [0.4255150932312012,
#   0.2792080213546753,
#   0.28059223585128784,
#   0.2997511515855789,
#   0.3354088755607605,
#   0.37603400654792785,
#   0.4144123887062073,
#   0.46077314891815185,
#   0.4986676251411438,
#   0.5390626512765885,
#   0.5741142279624939,
#   0.6083178394317627,
#   0.6330825273513794,
#   0.6596913993835449,
#   0.6853192895889282,
#   0.703524638491869,
#   0.7269420598983765,
#   0.7460530101776123,
#   0.7634012170791626,
#   0.7812286921977997],
#  'val_accuracy': [0.8675,
#   0.8865,
#   0.8804,
#   0.8771,
#   0.8715,
#   0.8675,
#   0.8648,
#   0.8628,
#   0.8608,
#   0.858,
#   0.8569,
#   0.8569,
#   0.8572,
#   0.8567,
#   0.8551,
#   0.8551,
#   0.855,
#   0.8544,
#   0.8539,
#   0.8538]}

# %%
epochs = range(1,21)
plt.figure(figsize=(8,8))
plt.plot(epochs, hist.history['loss'], color='blue', label='Train Loss')
plt.plot(epochs, hist.history['val_loss'], color='red', label='Validation Loss')
plt.title('Train, Test set Loss')
plt.legend()
plt.show()

# %%
epochs = range(1,21)
plt.figure(figsize=(8,8))
plt.plot(epochs, hist.history['accuracy'], color='blue', label='Train accuracy')
plt.plot(epochs, hist.history['val_accuracy'], color='red', label='Validation accuracy')
plt.title('Train, Test set accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### 테스트 셋으로 평가

# %%
model.evaluate(X_test_tfidf, y_test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'scipy.sparse.csr.csr_matrix'>, <class 'NoneType'>
# 25000/25000 [==============================] - 4s 171us/sample - loss: 0.9654 - accuracy: 0.8255
# [0.965404279859066, 0.82548]

# %% [markdown]
# ### 학습된 모델로 예측

# %%
pred = model.predict(X_test_tfidf[0])
pred
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'scipy.sparse.csr.csr_matrix'>, <class 'NoneType'>
# array([[0.00016157]], dtype=float32)

# %%
pred_cls = model.predict_classes(X_test_tfidf[0])
pred_cls
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'scipy.sparse.csr.csr_matrix'>, <class 'NoneType'>
# array([[0]])

# %%
y_test[0]
# Out:
# 1.0
